# %%
import requests                       #these are the modules used for the program
import json 
from googleplaces import GooglePlaces, types, lang


def currency_exch(exch_opt):    #this function is a separate program that is used to conduct currency exchage
    
    SUPPORTED_CURRENCIES = {                        #Dictionary of supported currencies from API
        "EUR": "European euro",
        "USD": "US dollar",
        "GBP": "Pound sterling",
        "BRL": "Brazilian real",
        "JPY": "Japanese yen",
        "BGN": "Bulgarian lev",
        "CZK": "Czech koruna",
        "DKK": "Danish krone",
        "GPB": "Pound sterling",
        "HUF": "Hungarian forint",
        "PLN": "Polish zloty",
        "RON": "Romanian leu",
        "SEK": "Swedish krona",
        "CHF": "Swiss franc",
        "NOK": "Norwegian krone",
        "HRK": "Croatian kuna",
        "RUB": "Russian rouble",
        "TRY": "Turkish lira",
        "AUD": "Australian dollar",
        "CAD": "Canadian dollar",
        "CNY": "Chinese yuan renminbi",
        "HKD": "Hong Kong dollar",
        "IDR": "Indonesian rupiah",
        "ILS": "Israeli shekel",
        "INR": "Indian rupee",
        "KRW": "South Korean won",
        "MXN": "Mexican peso",
        "MYR": "Malaysian ringgit",
        "NZD": "New Zealand dollar",
        "PHP": "Philippine piso",
        "SGD": "Singapore dollar",
        "THB": "Thai baht",
        "ZAR": "South African rand"
    }


    CURRENCY_CODES = {                       #Dictionary of options that user can choose from
        1: "EUR",
        2: "USD",
        3: "GBP",
        4: "BRL",
        5: "JPY",
        6: "BGN",
        7: "CZK",
        8: "DKK",
        9: "GPB",
        10: "HUF",
        11: "PLN",
        12: "RON",
        13: "SEK",
        14: "CHF",
        15: "NOK",
        16: "HRK",
        17: "RUB",
        18: "TRY",
        19: "AUD",
        20: "CAD",
        21: "CNY",
        22: "HKD",
        23: "IDR",
        24: "ILS",
        25: "INR",
        26: "KRW",
        27: "MXN",
        28: "MYR",
        29: "NZD",
        30: "PHP",
        31: "SGD",
        32: "THB",
        33: "ZAR"
    }

    if __name__ == '__main__':

        amount = float(input("Enter the amount you wish to convert: "))

        print("Choose a base currency among our supported currencies:")
        while True:# this loop serves as a error handling tool
            for code, currency in CURRENCY_CODES.items():#this loop prints out everything in the CURRENCY_CODES dictionary
                print("code {}: base {}".format(code, currency))
            base_currency_code = int(input("Please digit the code: "))
            if base_currency_code in CURRENCY_CODES.keys(): #condition to break loop
                break
            else:
                print("Invalid code")
        base_currency = CURRENCY_CODES[base_currency_code] #assigning selected base currency to variable

        print("Choose a target currency among our supported currencies:")
        while True: #this loop serves as a error handling tool
            for code, currency in CURRENCY_CODES.items(): #this loop prints each item in CURRENCY_CODES dictionary
                print("code {}: target {}".format(code, currency))
            target_currency_code = int(input("Please digit the code: "))
            if target_currency_code in CURRENCY_CODES.keys():#condition to break loop
                break
            else:
                print("Invalid code")
        target_currency = CURRENCY_CODES[target_currency_code] #target currency assigned to variable

        exchange_rate = get_exchange_rate(base_currency, target_currency) #variable to call function that gets data from API

        print("{} {} is {} {}".format(amount, base_currency, amount * exchange_rate, target_currency)) #prints results

def get_exchange_rate(base_currency, target_currency): #function to ping API for data
    if not (base_currency in SUPPORTED_CURRENCIES.keys()): #error handling tool
        raise ValueError("base currency {} not supported".format(base_currency)) #error message
    if not (target_currency in SUPPORTED_CURRENCIES.keys()): #error handling tool
        raise ValueError("target currency {} not supported".format(target_currency)) #error message

    if base_currency == target_currency: # error handing condition, to return same value if both currencies are the same
        return 1

    api_url = "https://api.fixer.io/latest?base={}&symbols={}".format(base_currency, target_currency) #url for API, with options
    api_response = requests.get(api_url)#get request to API

    if api_response.status_code == 200:#condition if API response good return data needed
        return api_response.json()["rates"][target_currency]


def ping_gplaces(option, latlng): #function to use googleplaces python module
    try:
        print('Below are establishments for the the option that you entered. Hopefully these results will help you in arranging your travel plans.')
        print('\n')
        # variable to search googleplaces
        query_result = google_places.text_search(query= option, language='en', lat_lng= latlng, radius=1000, type=None, types=[], location=None, pagetoken=None)

        if query_result.has_attributions: #condition to print statements if results are available
            print (query_result.html_attributions)

        for place in query_result.places: #for each result print the following
            place.get_details() #further call to api necessary for further details
            print (place.name)
            print ('Rating of %s out of 5' % place.rating)
            print ('The address of the establishment is: %s' % place.formatted_address)
            print ('Phone Number: %s' % place.local_phone_number)
            print ('International Phone Number: %s' % place.international_phone_number)
            print ('Website of establishment: %s' % place.website)
            print ('Google Places place url: %s' % place.url)
            print ('\n')
    
    except IndexError as e: #handle index errors
        print('Oops, something went wrong.', e, 'Please ensure that you enter an accurate location')

    except json.decoder.JSONDecodeError as e: #handle decoding errors
        print("ERROR: Cannot decode the response into json")
        print("DETAILS", e)

    except requests.exceptions.HTTPError as e: #handle bad response from url
        print("ERROR: Response from ", url, 'was not ok.')
        print("DETAILS:", e)

    except requests.exceptions.RequestException as e: #handle internet connection error
        print("ERROR: Cannot connect to ", url)
        print("DETAILS:", e)
    
def geocode(location): #function to use google maps to get coordinates
    url = 'http://maps.googleapis.com/maps/api/geocode/json' #api url

    options = { 'address' : location }  #api required parameters
    response = requests.get(url, params = options) #api request            
    geodata = response.json() #api response
    coords = geodata['results'][0]['geometry']['location'] #filtering of json data for required data
    return coords #return required data

# %%
import requests
import json 
from googleplaces import GooglePlaces, types, lang

try:
    apikey='AIzaSyBRITE0gle6KEIsA1Gta8lRy2KKNTkhAH8' #api key needed for googleplaces module
    google_places = GooglePlaces(apikey) #creating variable to use module with api key
    destination = input('Enter the location you wish to travel to (ex: Syracuse, NY): ')
    latlng_dest = geocode(destination) # call geocode function to return coordinates

    while True: #error handling tool
        hotel= input("Would you like to lookup hotels? (y or n) ")
        if hotel == 'y': #condition to continue with function call
            print('\n')
            hotel = 'hotel'
            hotel_query = ping_gplaces(hotel, latlng_dest) #function call
            break #break loop
        elif hotel == 'n': # secondary condition to break loop
            break
        else: #condition that reloops
            print('That is not a valid input. Enter either "y" or "n"')

    while True: #error handling tool
        restaurant= input("Would You like to lookup restaurants? (y or n) ")

        if restaurant == 'y': #condition to continue with function call
            res_spec = input('Is their any specific type of restauraunt you desire? (y or n) ')
            if res_spec == 'y': #condition to continue with function call with specific criteria
                res_type = input('Enter the type of restaurant the you desire (ex:Pizza): ')
                print('\n')
                res_search = ('%s restaurant' % res_type) #call function with specific criteria
                res_query = ping_gplaces(res_search, latlng_dest)
                break
            elif res_spec == 'n': #condition to call function with general criteria
                print('\n')
                res_search = ('restaurant' )
                res_query = ping_gplaces(res_search, latlng_dest) #call function
                break
            else: #condition to reloop
                print('That is not a valid input. Enter either "y" or "n"')
        elif restaurant == 'n': #condition to break loop
            None
            break
        else: #condition to reloop
            print('That is not a valid input. Enter either "y" or "n"')

    while True: #error handling tool
        transportation = input('Would you like to lookup public transportation? (y or no):')
        if transportation == 'y': #condition to continue with function call
            print('\n')
            transportation = ('taxi in %s' % destination)
            trans_query= ping_gplaces(transportation, latlng_dest) #call function
            break
        elif transportation == 'n': #condition to break loop
            break
        elif transportation is not 'y' or 'n': #condition to reloop
            print('That is not a valid input. Enter either "y" or "n"')

    while True: #error handling tool
        tour_attract = input('Would you like to lookup tourist attractions? (y or no):')
        if tour_attract == 'y': #condition to continue with function call
            print('\n')
            tour_attract = 'tourist attraction'
            trans_query= ping_gplaces(tour_attract, latlng_dest) #function call
            break
        elif tour_attract == 'n': #conditon to break loop
            break
        elif tour_attract is not 'y' or 'n': #condition to reloop
            print('That is not a valid input. Enter either "y" or "n"')    

    while True: #error handling tool
        exch_opt = input('Would you like to exchange currency (y or n)? ') 
        if exch_opt == 'y': #condition to call function
            currency_exch(exch_opt) #call function
            break
        elif exch_opt == 'n': #condition to break loop
            break
        elif exch_opt is not 'y' or 'n': #condition to reloop
            print('That is not a valid input. Enter either "y" or "n"')
            
except ValueError: #handle value errors
    print('Oops! Sorry, there seems to have been an issue. Please try again')
    
except IndexError: #handle index errors
    print('Oops! Sorry, there seems to have been an issue. Please try again')
# Out:
# Enter the location you wish to travel to (ex: Syracuse, NY): Barcelona, Spain
# Would you like to lookup hotels? (y or n) y
#
#
# Below are establishments for the the option that you entered. Hopefully these results will help you in arranging your travel plans.
#
#
# Violeta Boutique Hotel
# Rating of 4.5 out of 5
# The address of the establishment is: Carrer de Casp, 38, 08010 Barcelona, Spain
# Phone Number: 933 02 81 58
# International Phone Number: +34 933 02 81 58
# Website of establishment: http://www.violetaboutique.com/
# Google Places place url: https://maps.google.com/?cid=9505382083477128575
#
#
# Hotel Continental Palacete
# Rating of 4.1 out of 5
# The address of the establishment is: Rambla de Catalunya, 30, 08007 Barcelona, Spain
# Phone Number: 934 45 76 57
# International Phone Number: +34 934 45 76 57
# Website of establishment: http://www.hotelpalacete.com/
# Google Places place url: https://maps.google.com/?cid=4827396809825242306
#
#
# Hotel Catalonia Born
# Rating of 4.4 out of 5
# The address of the establishment is: Carrer del Rec Comtal, 16-18, 08003 Barcelona, Spain
# Phone Number: 932 68 86 00
# International Phone Number: +34 932 68 86 00
# Website of establishment: https://www.cataloniahotels.com/es/hotel/catalonia-born?withoutDates=1
# Google Places place url: https://maps.google.com/?cid=18130657791950369683
#
#
# Barcelone Hotels pas cher
# Rating of 2 out of 5
# The address of the establishment is: Carrer de Wellington, 27, 08018 Barcelona, Spain
# Phone Number: 603 49 34 58
# International Phone Number: +34 603 49 34 58
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=3810628268112703150
#
#
# DQ hotel
# Rating of  out of 5
# The address of the establishment is: Hotel DO: Plaça Reial Plaça Reial Barcelona Spain, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=3642492276748317255
#
#
# Generator Hotel
# Rating of  out of 5
# The address of the establishment is: 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=3874829378823971629
#
#
# Hotel i barcelona
# Rating of  out of 5
# The address of the establishment is: Carrer del Bruc, 16, 08010 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=11446150591352981285
#
#
# hotel arc la rambla
# Rating of  out of 5
# The address of the establishment is: Gran Via de les Corts Catalanes, 08010 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: https://hotelarclarambla.com/
# Google Places place url: https://maps.google.com/?cid=906449140110552647
#
#
# Hotel smart room
# Rating of 5 out of 5
# The address of the establishment is: 08002 Barcelona, Spain
# Phone Number: 934 31 18 64
# International Phone Number: +34 934 31 18 64
# Website of establishment: http://smartroombarcelona.com/es/
# Google Places place url: https://maps.google.com/?cid=8784033770990818614
#
#
# HOTEL COSTANZA
# Rating of  out of 5
# The address of the establishment is: E-9, 08007 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: http://hotelconstanza.com/
# Google Places place url: https://maps.google.com/?cid=1688758585329054177
#
#
# hotel st moritz
# Rating of  out of 5
# The address of the establishment is: Plaça de Catalunya, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=15111634875202589744
#
#
# The Hotel 592
# Rating of 4 out of 5
# The address of the establishment is: Gran Via de les Corts Catalanes, 592, 08007 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: http://www.thehotel592.com/
# Google Places place url: https://maps.google.com/?cid=16056347866411421973
#
#
# Hotel DO
# Rating of 1 out of 5
# The address of the establishment is: Passeig de Gràcia, 08007 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: http://www.hoteldoreial.com/hotel-overview.html
# Google Places place url: https://maps.google.com/?cid=736604739908246921
#
#
# Hotel Alba
# Rating of  out of 5
# The address of the establishment is: Plaça de Catalunya, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=13347444182730549277
#
#
# OD Barcelona
# Rating of 4.3 out of 5
# The address of the establishment is: Carrer d'Aragó, 300, 08009 Barcelona, Spain
# Phone Number: 932 15 08 99
# International Phone Number: +34 932 15 08 99
# Website of establishment: http://www.odbarcelona.com/
# Google Places place url: https://maps.google.com/?cid=12850653606961939110
#
#
# Hotel Oasis
# Rating of 3.8 out of 5
# The address of the establishment is: Pla de Palau, 17, 08003 Barcelona, Spain
# Phone Number: 933 19 43 96
# International Phone Number: +34 933 19 43 96
# Website of establishment: http://www.hoteloasis.es/
# Google Places place url: https://maps.google.com/?cid=4219377073209287451
#
#
# Hotel Denit Barcelona
# Rating of 4 out of 5
# The address of the establishment is: Carrer d'Estruc, 24, 08002 Barcelona, Spain
# Phone Number: 935 45 40 00
# International Phone Number: +34 935 45 40 00
# Website of establishment: http://www.denit.com/
# Google Places place url: https://maps.google.com/?cid=11785646431886247450
#
#
# Hotel chic&basic Ramblas
# Rating of 4.1 out of 5
# The address of the establishment is: Passatge de Gutenberg, 7, 08001 Barcelona, Spain
# Phone Number: 933 02 71 11
# International Phone Number: +34 933 02 71 11
# Website of establishment: http://www.chicandbasicramblashotel.com/
# Google Places place url: https://maps.google.com/?cid=8405150250420980151
#
#
# Hotel Praktik Vinoteca
# Rating of 4.5 out of 5
# The address of the establishment is: Carrer de Balmes, 51, 08007 Barcelona, Spain
# Phone Number: 934 54 50 28
# International Phone Number: +34 934 54 50 28
# Website of establishment: http://www.hotelpraktikvinoteca.com/es
# Google Places place url: https://maps.google.com/?cid=17082256891625540070
#
#
# Hotel Acta BCN 40
# Rating of 3.9 out of 5
# The address of the establishment is: Carrer de Joaquín Costa, 40, 08001 Barcelona, Spain
# Phone Number: 933 18 51 00
# International Phone Number: +34 933 18 51 00
# Website of establishment: http://www.hotel-bcn40barcelona.com/
# Google Places place url: https://maps.google.com/?cid=11291332511710443213
#
#
# Would You like to lookup restaurants? (y or n) y
# Is their any specific type of restauraunt you desire? (y or n) y
# Enter the type of restaurant the you desire (ex:Pizza): Pizza
#
#
# Below are establishments for the the option that you entered. Hopefully these results will help you in arranging your travel plans.
#
#
# Pizzeria Restaurant del Barri
# Rating of 4.4 out of 5
# The address of the establishment is: Passeig de Pujades, 25, 08018 Barcelona, Spain
# Phone Number: 936 24 37 49
# International Phone Number: +34 936 24 37 49
# Website of establishment: http://www.restaurantdelbarri.com/
# Google Places place url: https://maps.google.com/?cid=16995704855996867035
#
#
# La Pizza Pazza
# Rating of 4.6 out of 5
# The address of the establishment is: Carrer Ample, 44, 08002 Barcelona, Spain
# Phone Number: 931 79 44 37
# International Phone Number: +34 931 79 44 37
# Website of establishment: http://www.pizzapazza-bcn.com/
# Google Places place url: https://maps.google.com/?cid=1035184743467920385
#
#
# Focacceria Toscana "Pizza al Taglio"
# Rating of 4.5 out of 5
# The address of the establishment is: Carrer de Ferran, 41, 08002 Barcelona, Spain
# Phone Number: 933 17 80 13
# International Phone Number: +34 933 17 80 13
# Website of establishment: http://www.focacceriatoscana.com/
# Google Places place url: https://maps.google.com/?cid=8354807622692808064
#
#
# La Pizza Del Born
# Rating of 4.3 out of 5
# The address of the establishment is: Passeig del Born, 22, 08003 Barcelona, Spain
# Phone Number: 933 10 62 46
# International Phone Number: +34 933 10 62 46
# Website of establishment: http://www.lapizzadelborn.com/
# Google Places place url: https://maps.google.com/?cid=2100970923612466755
#
#
# Più Restaurants - Barcelona
# Rating of 3.6 out of 5
# The address of the establishment is: Gran Via de les Corts Catalanes, 633, 08007 Barcelona, Spain
# Phone Number: 934 12 78 83
# International Phone Number: +34 934 12 78 83
# Website of establishment: http://www.restaurantspiu.com/
# Google Places place url: https://maps.google.com/?cid=467682195630904278
# Pizza Paco S.l.
# Rating of 3.8 out of 5
# The address of the establishment is: Carrer de l'Allada-Vermell, 11, 08003 Barcelona, Spain
# Phone Number: 932 69 03 15
# International Phone Number: +34 932 69 03 15
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=11897932720228087568
#
#
# Caruso Barcelona Restaurant
# Rating of 2.1 out of 5
# The address of the establishment is: La Rambla, 96, 08002 Barcelona, Spain
# Phone Number: 933 01 81 79
# International Phone Number: +34 933 01 81 79
# Website of establishment: http://www.grupoamt.es/
# Google Places place url: https://maps.google.com/?cid=249688321483167634
#
#
# Pizza Emporio
# Rating of 3.5 out of 5
# The address of the establishment is: Rambla de Catalunya, 13, 08007 Barcelona, Spain
# Phone Number: 933 42 70 51
# International Phone Number: +34 933 42 70 51
# Website of establishment: http://www.pizzaemporio.com.es/
# Google Places place url: https://maps.google.com/?cid=8758897458705806666
#
#
# Pizzas l'Avia Restaurant
# Rating of 4.2 out of 5
# The address of the establishment is: Carrer de la Cera, 33, 08001 Barcelona, Spain
# Phone Number: 934 42 00 97
# International Phone Number: +34 934 42 00 97
# Website of establishment: http://pizzas-lavia.eltenedor.rest/
# Google Places place url: https://maps.google.com/?cid=14946012467101962226
#
#
# Pizza Circus
# Rating of 4.7 out of 5
# The address of the establishment is: Carrer Nou de la Rambla, 40, 08001 Barcelona, Spain
# Phone Number: 934 12 38 10
# International Phone Number: +34 934 12 38 10
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=8247970661941936902
#
#
# NAP Antic
# Rating of 4.4 out of 5
# The address of the establishment is: Av. de Francesc Cambó, 30, 08003 Barcelona, Spain
# Phone Number: 686 19 26 90
# International Phone Number: +34 686 19 26 90
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=9634594428216300838
#
#
# Taller de Pizza
# Rating of 4 out of 5
# The address of the establishment is: Calle Aragó, 309, 08009 Barcelona, Spain
# Phone Number: 931 19 59 90
# International Phone Number: +34 931 19 59 90
# Website of establishment: https://m.facebook.com/tallerdepizzabcn/
# Google Places place url: https://maps.google.com/?cid=5700029282392904370
#
#
# Restaurant Margherita
# Rating of 4.3 out of 5
# The address of the establishment is: Carrer del Rosselló, 253, 08008 Barcelona, Spain
# Phone Number: 936 11 56 67
# International Phone Number: +34 936 11 56 67
# Website of establishment: http://www.ristorantemargheritabcn.com/
# Google Places place url: https://maps.google.com/?cid=1733163132122385290
#
#
# Vicino Pizza Bar
# Rating of 4.4 out of 5
# The address of the establishment is: Passeig de Joan de Borbó, 68, 08003 Barcelona, Spain
# Phone Number: 933 15 78 38
# International Phone Number: +34 933 15 78 38
# Website of establishment: http://vicino.es/
# Google Places place url: https://maps.google.com/?cid=4613931854881962110
#
#
# Solo Pizza (pizzeria romana)
# Rating of 4.1 out of 5
# The address of the establishment is: Carrer d'Enric Granados, 108, 08008 Barcelona, Spain
# Phone Number: 933 68 33 50
# International Phone Number: +34 933 68 33 50
# Website of establishment: http://solo-pizza.eltenedor.rest/
# Google Places place url: https://maps.google.com/?cid=8644672064973363796
#
#
# Parking Pizza
# Rating of 4.3 out of 5
# The address of the establishment is: Carrer de Londres, 98, 08036 Barcelona, Spain
# Phone Number: 936 33 96 45
# International Phone Number: +34 936 33 96 45
# Website of establishment: http://www.parkingpizza.com/
# Google Places place url: https://maps.google.com/?cid=1911841422330742428
#
#
# Messié Pizza
# Rating of 4.2 out of 5
# The address of the establishment is: Carrer del Torrent de l'Olla, 65, 08012 Barcelona, Spain
# Phone Number: 932 18 93 45
# International Phone Number: +34 932 18 93 45
# Website of establishment: http://www.messiepizza.es/
# Google Places place url: https://maps.google.com/?cid=121690811597668594
#
#
# Pizzeria Mario 2
# Rating of 4.4 out of 5
# The address of the establishment is: Av. de Sarrià, 15, 08029 Barcelona, Spain
# Phone Number: 934 10 30 37
# International Phone Number: +34 934 10 30 37
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=13226357088738475044
#
#
# Pizzería Ninones Restaurant
# Rating of 3.3 out of 5
# The address of the establishment is: Ronda del Guinardó, 114, 08041 Barcelona, Spain
# Phone Number: 934 46 24 84
# International Phone Number: +34 934 46 24 84
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=7494672132253394853
#
#
# La Toscana
# Rating of 4 out of 5
# The address of the establishment is: C/ Neopàtria, 87, 08030 Barcelona, Spain
# Phone Number: 933 45 34 05
# International Phone Number: +34 933 45 34 05
# Website of establishment: http://www.latoscanasantandreu.com/
# Google Places place url: https://maps.google.com/?cid=962287744429983919
#
#
# Would you like to lookup public transportation? (y or no):y
#
#
# Below are establishments for the the option that you entered. Hopefully these results will help you in arranging your travel plans.
#
#
# Premium Car Transfers
# Rating of 5 out of 5
# The address of the establishment is: Carrer de Nàpols, 120 3º 4ª, 08013 Barcelona, Spain
# Phone Number: 618 79 47 22
# International Phone Number: +34 618 79 47 22
# Website of establishment: http://premiumcartransfers.com/
# Google Places place url: https://maps.google.com/?cid=6091148441442167072
#
#
# Taxi Eco Logic Barcelona
# Rating of  out of 5
# The address of the establishment is: Carrer de Santander, 23, 08020 Barcelona, Spain
# Phone Number: 932 78 30 00
# International Phone Number: +34 932 78 30 00
# Website of establishment: http://taxiecologic.com/
# Google Places place url: https://maps.google.com/?cid=12817692231762899561
#
#
# BARNATAXI
# Rating of 2 out of 5
# The address of the establishment is: Passeig de Pujades, 23, 08018 Barcelona, Spain
# Phone Number: 933 22 22 22
# International Phone Number: +34 933 22 22 22
# Website of establishment: http://www.barnataxi.com/
# Google Places place url: https://maps.google.com/?cid=11829800429370683230
#
#
# Catalunyataxi Com.
# Rating of 5 out of 5
# The address of the establishment is: Carrer del Rosselló, 478, 08025 Barcelona, Spain
# Phone Number: 931 14 54 44
# International Phone Number: +34 931 14 54 44
# Website of establishment: http://www.catalunyataxi.com/
# Google Places place url: https://maps.google.com/?cid=5202108569020938425
#
#
# Parada Taxi Plaça Catalunya
# Rating of 3 out of 5
# The address of the establishment is: Plaça de Catalunya, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=13846960931496023332
#
#
# Parada de Taxis Barcelona-Sants
# Rating of 2.7 out of 5
# The address of the establishment is: Plaça de Joan Peiró, 9999, 08014 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: http://taxi.amb.cat/es/usuari
# Google Places place url: https://maps.google.com/?cid=3011173022142963205
#
#
# Stac
# Rating of 3.8 out of 5
# The address of the establishment is: Carrer de la Marina, 82, 08018 Barcelona, Spain
# Phone Number: 933 00 23 14
# International Phone Number: +34 933 00 23 14
# Website of establishment: http://www.stac.cat/
# Google Places place url: https://maps.google.com/?cid=5797824467190327353
#
#
# Taxi Barcelona
# Rating of 3.2 out of 5
# The address of the establishment is: Carrer de Guitard, 74, 08014 Barcelona, Spain
# Phone Number: 644 97 29 72
# International Phone Number: +34 644 97 29 72
# Website of establishment: http://taxibarcelona.co/
# Google Places place url: https://maps.google.com/?cid=14288797310088892624
#
#
# Taxi Estrella Barcelona SL
# Rating of  out of 5
# The address of the establishment is: Carrer Amílcar, 182, 08032 Barcelona, Spain
# Phone Number: 934 33 52 32
# International Phone Number: +34 934 33 52 32
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=9519178462861745197
#
#
# Taxi Miramar, S.L.
# Rating of 2.3 out of 5
# The address of the establishment is: Carrer de Llull, 93, 08005 Barcelona, Spain
# Phone Number: 934 33 10 20
# International Phone Number: +34 934 33 10 20
# Website of establishment: http://www.taximiramar.com/
# Google Places place url: https://maps.google.com/?cid=16103218442193234915
# Anfe Taxi S L
# Rating of  out of 5
# The address of the establishment is: Carrer de Villar, 45, 08041 Barcelona, Spain
# Phone Number: 934 35 88 84
# International Phone Number: +34 934 35 88 84
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=8965389574684692864
#
#
# La Casa Del Taxi
# Rating of 3.3 out of 5
# The address of the establishment is: Carrer de Bac de Roda, 89, 08005 Barcelona, Spain
# Phone Number: 933 07 47 27
# International Phone Number: +34 933 07 47 27
# Website of establishment: http://www.hitcon.es/
# Google Places place url: https://maps.google.com/?cid=4011517205957192872
#
#
# Corbel Taxi
# Rating of  out of 5
# The address of the establishment is: Carrer de Cartagena, 378, 08024 Barcelona, Spain
# Phone Number: 931 79 77 68
# International Phone Number: +34 931 79 77 68
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=8823189526957424816
#
#
# VIP TAXI
# Rating of  out of 5
# The address of the establishment is: Carrer de Josep Sangenís, 10, 08035 Barcelona, Spain
# Phone Number: 934 29 33 00
# International Phone Number: +34 934 29 33 00
# Website of establishment: http://www.viptaxi.net/
# Google Places place url: https://maps.google.com/?cid=8291872919382475314
#
#
# Would you like to lookup tourist attractions? (y or no):y
#
#
# Below are establishments for the the option that you entered. Hopefully these results will help you in arranging your travel plans.
#
#
# Place Nova
# Rating of 4.5 out of 5
# The address of the establishment is: Plaça Nova, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=3700081544763828035
#
#
# Plaça de Catalunya
# Rating of 4.4 out of 5
# The address of the establishment is: Plaça de Catalunya, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: http://w110.bcn.cat/portal/site/Turisme/menuitem.7e257cdd389697aa58cb0d3020348a0c/?vgnextoid=0000001192989213VgnV6CONT00000000000RCRD&lang=ca_ES
# Google Places place url: https://maps.google.com/?cid=2228369972992726603
#
#
# Free Walking Tours Barcelona
# Rating of 4.8 out of 5
# The address of the establishment is: Plaça de Catalunya, s/n, 08193 Barcelona, Spain
# Phone Number: 622 65 18 14
# International Phone Number: +34 622 65 18 14
# Website of establishment: http://freewalkingtoursbarcelona.com/
# Google Places place url: https://maps.google.com/?cid=6769174010765214339
#
#
# Casa Batlló
# Rating of 4.6 out of 5
# The address of the establishment is: Passeig de Gràcia, 43, 08007 Barcelona, Spain
# Phone Number: 932 16 03 06
# International Phone Number: +34 932 16 03 06
# Website of establishment: https://www.casabatllo.es/
# Google Places place url: https://maps.google.com/?cid=4670927909449256463
#
#
# Plaça Sant Jaume
# Rating of 4.3 out of 5
# The address of the establishment is: Plaça de Sant Jaume, 1, 08002 Barcelona, Spain
# Phone Number: 934 02 70 00
# International Phone Number: +34 934 02 70 00
# Website of establishment: http://www.bcn.cat/
# Google Places place url: https://maps.google.com/?cid=9755799218953007950
#
#
# Basilica of Santa Maria del Mar
# Rating of 4.7 out of 5
# The address of the establishment is: Plaça de Santa Maria, 1, 08003 Barcelona, Spain
# Phone Number: 933 10 23 90
# International Phone Number: +34 933 10 23 90
# Website of establishment: http://www.santamariadelmarbarcelona.org/home/
# Google Places place url: https://maps.google.com/?cid=13023447345839268192
#
#
# Aquarium Barcelona
# Rating of 3.9 out of 5
# The address of the establishment is: Moll d'Espanya del Port Vell, s/n, 08039 Barcelona, Spain
# Phone Number: 932 21 74 74
# International Phone Number: +34 932 21 74 74
# Website of establishment: http://www.aquariumbcn.com/
# Google Places place url: https://maps.google.com/?cid=4260425396936874336
#
#
# Barcelona Tours And Event Management
# Rating of 5 out of 5
# The address of the establishment is: Gran Via de les Corts Catalanes, 594, 08007 Barcelona, Spain
# Phone Number: 675 58 28 78
# International Phone Number: +34 675 58 28 78
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=5542174843845640384
#
#
# Columbus Monument, Barcelona
# Rating of 4.3 out of 5
# The address of the establishment is: Plaça Portal de la pau, 08001 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=3088355323810639031
#
#
# Barcelona Photography Courses
# Rating of  out of 5
# The address of the establishment is: Carrer de Buenaventura Muñoz, 9, 08018 Barcelona, Spain
# Phone Number: 635 40 41 86
# International Phone Number: +34 635 40 41 86
# Website of establishment: http://www.barcelonaphotographycourses.com/
# Google Places place url: https://maps.google.com/?cid=17026743899850926616
#
#
# Illa de la Discòrdia
# Rating of 4.4 out of 5
# The address of the establishment is: Passeig de Gràcia, 41, 08007 Barcelona, Spain
# Phone Number: 670 46 62 60
# International Phone Number: +34 670 46 62 60
# Website of establishment: http://www.mansanadeladiscordia.com/
# Google Places place url: https://maps.google.com/?cid=5644656711353462325
#
#
# Flippa Barcelona
# Rating of  out of 5
# The address of the establishment is: Carrer d'Aragó, 231, 08007 Barcelona, Spain
# Phone Number: 934 67 22 80
# International Phone Number: +34 934 67 22 80
# Website of establishment: http://www.flippa.es/
# Google Places place url: https://maps.google.com/?cid=2293563533908070304
#
#
# Blue Shirt Barcelona
# Rating of  out of 5
# The address of the establishment is: Carrer d'En Botella, 14, 08001 Barcelona, Spain
# Phone Number: 680 60 59 31
# International Phone Number: +34 680 60 59 31
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=1457743568686622766
#
#
# Mirador del Rei Martí
# Rating of 4.1 out of 5
# The address of the establishment is: Plaça de Sant Iu, 4, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=8534092435518774301
#
#
# Palau Centelles
# Rating of 4.2 out of 5
# The address of the establishment is: Baixada de Sant Miquel, 8, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=9873741295786109716
#
#
# Font Pla de la Boquería
# Rating of 3.3 out of 5
# The address of the establishment is: Pla de la Boqueria, 3, 08002 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=6982922143354870981
#
#
# Cases Antoni Rocamora
# Rating of 4.8 out of 5
# The address of the establishment is: Passeig de Gràcia, 6, 08007 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=3039963019357021094
#
#
# Maximum Escape 1
# Rating of 4.7 out of 5
# The address of the establishment is: Carrer de Girona, 27, 08010 Barcelona, Spain
# Phone Number: 933 18 01 55
# International Phone Number: +34 933 18 01 55
# Website of establishment: https://barcelona.maximumescape.com/
# Google Places place url: https://maps.google.com/?cid=4845070896033513993
#
#
# LudoParks
# Rating of  out of 5
# The address of the establishment is: Rambla de Catalunya, 43, 08007 Barcelona, Spain
# Phone Number: 933 30 78 00
# International Phone Number: +34 933 30 78 00
# Website of establishment: https://ludoparks.com/
# Google Places place url: https://maps.google.com/?cid=6962082398095910355
#
#
# La Bodegguita
# Rating of 4.4 out of 5
# The address of the establishment is: Carrer del Comte Borrell, 16, 08015 Barcelona, Spain
# Phone Number: None
# International Phone Number: None
# Website of establishment: None
# Google Places place url: https://maps.google.com/?cid=16276685623775083267
#
#
# Would you like to exchange currency (y or n)? y
# Enter the amount you wish to convert: 1000
# Choose a base currency among our supported currencies:
# code 1: base EUR
# code 2: base USD
# code 3: base GBP
# code 4: base BRL
# code 5: base JPY
# code 6: base BGN
# code 7: base CZK
# code 8: base DKK
# code 9: base GPB
# code 10: base HUF
# code 11: base PLN
# code 12: base RON
# code 13: base SEK
# code 14: base CHF
# code 15: base NOK
# code 16: base HRK
# code 17: base RUB
# code 18: base TRY
# code 19: base AUD
# code 20: base CAD
# code 21: base CNY
# code 22: base HKD
# code 23: base IDR
# code 24: base ILS
# code 25: base INR
# code 26: base KRW
# code 27: base MXN
# code 28: base MYR
# code 29: base NZD
# code 30: base PHP
# code 31: base SGD
# code 32: base THB
# code 33: base ZAR
# Please digit the code: 2
# Choose a target currency among our supported currencies:
# code 1: target EUR
# code 2: target USD
# code 3: target GBP
# code 4: target BRL
# code 5: target JPY
# code 6: target BGN
# code 7: target CZK
# code 8: target DKK
# code 9: target GPB
# code 10: target HUF
# code 11: target PLN
# code 12: target RON
# code 13: target SEK
# code 14: target CHF
# code 15: target NOK
# code 16: target HRK
# code 17: target RUB
# code 18: target TRY
# code 19: target AUD
# code 20: target CAD
# code 21: target CNY
# code 22: target HKD
# code 23: target IDR
# code 24: target ILS
# code 25: target INR
# code 26: target KRW
# code 27: target MXN
# code 28: target MYR
# code 29: target NZD
# code 30: target PHP
# code 31: target SGD
# code 32: target THB
# code 33: target ZAR
# Please digit the code: 1
# 1000.0 USD is 851.64 EUR
